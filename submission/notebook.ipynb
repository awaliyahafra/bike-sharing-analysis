# %% [markdown]
# # Proyek Analisis Data: [Bike Sharing Dataset]
# - **Nama:** [Zahrotun Awaliyah Afra]
# - **Email:** [zahrotunawaliyahafra088@gmail.com]
# - **ID Dicoding:** [Zahrotun awaliyah afra]

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# **SMART Question** adalah sebuah framework untuk merumuskan pertanyaan secara terstruktur agar memeperoleh informasi yang mendalam.
#
# * **Spesific (Spesifik)**
#   * Pertanyaan harus jelas, fokus pada sebuah topik tertentu, dan tidak bermakna ganda. Hindari pertanyaan yang terlalu luas.
#     * Salah: Bagaimana cara meningkatkan penjualan?
#     * Benar: Faktor apa saja yang memengaruhi penurunan penjualan produk kategori elektronik di wilayah Jakarta selama kuartal terakhir?
# * **Measurable (Terukur)**
#   * Pertanyaan harus bisa dijawab dengan angka atau matrix yang konkret, harus tahu apa yang akan dihitung.
#     * Salah: Apakah pelanggan senang dengan layanan kita?
#     * Benar: Berapa skor rata-rata Customer Satisfaction untuk layanan purna jual bulan ini dibandingkan bulan lalu?
# * **Action-Oriented (Berorientasi Aksi)**
#   * Hasil dari pertanyaan harus bisa memberikan arahan untuk melakukan tindakan nyata. Jika pertanyaan terjawab, stakeholder harus tahu apa langkah selanjutnya.
#     * Salah: Mengapa orang suka berbelanja?
#     * Benar: Fitur apa pada aplikasi yang paling sering digunakan sebelum pengguna memutuskan untuk melakukan checkout?
# * **Relevant (Relevan)**
#   * Hasil dari pertanyaan harus sejalan dengan tujuan utama bisnis atau masalah yang sedang dihadapi.
#     * Salah: Menanyakan tentang stok gudang saat masalah utamanya adalah efektivitas kampanye media sosial.
#     * Benar: Apakah kampanye iklan di Instagram memberikan Return on Ad Spend (ROAS) yang lebih tinggi dibandingkan iklan di TikTok?
# * **Time-bound (Terikat Waktu)**
#   * Pertanyaan harus ada batasan waktu yang jelas agar analisis memiliki konteks yang tepat.
#     * Salah: Berapa banyak pengguna baru kita?
#     * Benar: Berapa tingkat pertumbuhan pengguna baru secara bulanan (Month-over-Month) sepanjang tahun 2025?

# %% [markdown]
# **Contoh pertanyaan bisnis yang memenuhi seluruh elemen SMART**
#
# ***"Faktor apa saja yang memengaruhi penurunan conversion rate pada pengguna aplikasi Android di wilayah Jabodetabek sebesar 5% selama periode Flash Sale Maret 2026?"***
#
# Keterangan:
#
# - **Specific**: Fokus pada "penurunan conversion rate" untuk "aplikasi Android" di "Jabodetabek". Bukan sekadar penjualan turun.
# - **Measurable**: Ada angka konkret yang ingin dianalisis, yaitu penurunan sebesar "5%".
# - **Action-Oriented**: Dengan mengetahui faktor penyebabnya misalnya bug pada versi Android tertentu atau kendala logistik di Jabodetabek, tim bisa langsung melakukan perbaikan teknis atau operasional.
# - **Relevant**: Penurunan konversi saat Flash Sale adalah masalah kritis bagi bisnis retail/e-commerce.
# - **Time-bound**: Dibatasi pada periode spesifik "Flash Sale Maret 2026".

# %% [markdown]
# - **Pertanyaan 1:** Bagaimana kondisi cuaca terhadap rata-rata jumlah penyewaan sepeda harian selama tahun 2011-2012?
# - **Pertanyaan 2:** Bagaimana tren jumlah penyewaan sepeda berdasarkan musim selama tahun 2011-2012 dan musim mana yang memberikan kontribusi penyewaaan tertinggi?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %%
day_df = pd.read_csv("day.csv")
hour_df = pd.read_csv("hour.csv")

day_df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %% [markdown]
# ### Assessing Data

# %%
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %%
hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %%
day_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
hour_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
day_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
hour_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
day_df.dtypes
# Out:
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %%
day_df.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# ...

# %%
hour_df.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %% [markdown]
# **Insight:** (Opsional)
# - Tidak ditemukan missing value pada dataset day.csv maupun hour csv.
# - Tidak ditemukan data duplikat pada kedua dataset
# - Kolom dteday masih bertipe objet sehingga perlu dikonverensi menjadi datetime untuk mendukung analisis berbasis waktu
# - Berdasarkan statistika deskriptif, beberapa variabel numerik memiliki rentang nilai yang cukup lebar sehingga perlu diperhatikan dalam proses analisis

# %% [markdown]
# **Steps to Take:** (Opsional)
# - Mengubah tipe data kolom dteday dari object menjadi datetime
# - Melakukan validasi ulang setelah proses konversi tipe data
# - Menggunakan statistika deskriptif sebagai acuan untuk memahami karakteristik data sebelum tahap EDA

# %% [markdown]
# ### Gathering Data

# %%
day_df = pd.read_csv("day.csv")
hour_df = pd.read_csv("hour.csv")

day_df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %% [markdown]
# #### Load df ...

# %%
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %%
hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %%
day_df.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# ...

# %%
hour_df.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %% [markdown]
# **Insight:** (Opsional)
# - Dataset harian (day_df) memiliki 731 observasi, sedangkan dataset per jam (hour_df) memiliki 17.379 observasi
# - Tidak ditemukan indikasi missing value berdasarkan hasil pemeriksaan info ().
# - Kolom dteday masih bertipe object sehingga perlu diubah menjadi datetime pada tahap cleaning data.

# %% [markdown]
# #### Identifying ... problem

# %%
day_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
hour_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
day_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
hour_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
day_df.dtypes
# Out:
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %% [markdown]
# **Steps to Take:**
# - Mengubah tipe data kolom dteday dari object menjadi datetime.
# - Melakukan validasi ulang terhadap dataset setelah proses konversi tipe data sebelum melanjutkan ke tahap EDA.

# %% [markdown]
# **Insight:** (Opsional)
# - Tidak ditemukan missing value pada dataset dat.csv maupun hour csv.
# - Tidak ditemukan data duplikat pada kedua dataset.
# - Kolom dteday masih bertipe object dan perlu dikonversi menjadi datetime agar digunakan untuk analisis berbasis waktu.

# %% [markdown]
# ### Cleaning Data

# %%
day_df['dteday'] = pd.to_datetime(day_df['dteday'])
hour_df['dteday'] = pd.to_datetime(hour_df['dteday'])

# %%
day_df.dtypes
# Out:
# instant                int64
# dteday        datetime64[ns]
# season                 int64
# yr                     int64
# mnth                   int64
# holiday                int64
# weekday                int64
# workingday             int64
# weathersit             int64
# temp                 float64
# atemp                float64
# hum                  float64
# windspeed            float64
# casual                 int64
# registered             int64
# cnt                    int64
# dtype: object

# %%
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    datetime64[ns]
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(11)
# memory usage: 91.5 KB

# %% [markdown]
# #### Fixing ... problem

# %%
day_df['dteday'] = pd.to_datetime(day_df['dteday'])
hour_df['dteday'] = pd.to_datetime(hour_df['dteday'])

day_df.info()
hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    datetime64[ns]
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(11)
# memory usage: 91.5 KB
# <class 'pandas.core.frame.DataFrame'>
# ...

# %% [markdown]
# **Insight:** (Opsional)
# - Kolom dteday berhasil dikonversikan menjadi datetime64[ns].
# - Tidak ditemukan missing value maupun duplicate data pada dataset.
# - Dataset siap digunakan untuk proses EDA dan visualisasi.

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %% [markdown]
# EDA PERTANYAAN 1

# %%
weather_map = {
    1: 'Clear',
    2: 'Mist',
    3: 'Light Rain/Snow',
    4: 'Heavy Rain/Snow'
}

day_df['weather_label'] = day_df['weathersit'].map(weather_map)


weather_analysis = day_df.groupby('weather_label')['cnt'].mean().sort_values(ascending=False)

weather_analysis
# Out:
# weather_label
# Clear              4876.786177
# Mist               4035.862348
# Light Rain/Snow    1803.285714
# Name: cnt, dtype: float64

# %% [markdown]
# **Insight:** (Opsional)
# - Kondisi cuaca cerah (Clear) menghasilkan rata-rata jumlah penyewaan sepeda tertinggi, yaitu sekitar 4.876 penyewaan per hari.
# - Jumlah penyewaan menurun menjadi sekitar 4.035 penyewaan per hari saat cuaca berkabut (Mist).
# - Kondisi cuaca buruk seperti hujan ringan atau salju (Light Raint/Snow) memiliki rata-rata penyewaan terendah, yaitu sekitar 1.803 penyewaan per hari.
# - Hasil ini menunjukkan bahwa kondisi cuaca memiliki pengaruh yang signifikan terhadap tingkat penggunaan layanan bike sharing.

# %% [markdown]
# EDA PERTANYAAN 2

# %%
season_map = {
    1: 'Spring',
    2: 'Summer',
    3: 'Fall',
    4: 'Winter'
}

day_df['season_label'] = day_df['season'].map(season_map)

season_analysis = day_df.groupby('season_label')['cnt'].mean().sort_values(ascending=False)

season_analysis
# Out:
# season_label
# Fall      5644.303191
# Summer    4992.331522
# Winter    4728.162921
# Spring    2604.132597
# Name: cnt, dtype: float64

# %% [markdown]
# **Insight:** (Opsional)
# -  Musim Fall memiliki rata-rata jumlah penyewaan sepeda tertinggi, yaitu sekitar 5.644 penyewaan per hari.
# - Musim Summer dan Winter juga menunjukkan tingkat penyewaan yang relatif tinggi, yaitu masing-masing 4.992 dan 4.728 penyewaan per hari.
# - Musim Spring memiliki rata-rata jumlah penyewaan terendah, yaitu sekitar 2.604 penyewaan per hari.
# - Perbedaan jumlah penyewaan antar musim menunjukkan adanya pola permintaan yang dipengaruhi oleh kondisi musim dan lingkungan.

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:

# %%
plt.figure(figsize=(8, 5))

sns.barplot(
    x=weather_analysis.index,
    y=weather_analysis.values
)

plt.title('Rata-rata Penyewaan Sepeda Berdasarkan Kondisi Cuaca (2011-2012)')
plt.xlabel('Kondisi Cuaca')
plt.ylabel('Rata-rata Jumlah Penyewaan')
plt.show()

# %% [markdown]
# **Insight:** (Opsional)
# - Kondisi cuaca cerah menghasilkan rata-rata penyewaan tertinggi.
# - Penyewaan menurun saat cuaca berkabut.
# - Kondisi cuaca yang kurang baik berpengaruh terhadap penurunan jumlah penyewaan sepada.
# - Cuaca merupakan faktor penting yang memengaruhi penggunaan layanan Bike Sharing.

# %% [markdown]
# ### Pertanyaan 2:

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    x=season_analysis.index,
    y=season_analysis.values
)

plt.title('Rata-rata Penyewaan Sepeda Berdasarkan Musim (2011-2012)')
plt.xlabel('Musim')
plt.ylabel('Rata-rata Jumlah Penyewaan')
plt.show()

# %% [markdown]
# **Insight:** (Opsional)
# - Musim Fall memiliki rata-rata jumlah penyewaan sepeda tertinggi, yaitu sekitar 5.644 penyewaan per hari.
# - Musim Summer dan Winter juga menunjukkan tingkat penyewaan relatif tinggi denfan rata-rata sekitar 4.992 dan 4.728 penyewaan per hari.
# - Musim Spring memiliki rata-rata jumlah penyewaan terendah yaitu 2.604 per hari.
# - Hasik ini menunjukkan bahwa terdapat pola musiman pada penggunaan layanan Bike Sharing, dimana musim tertentu mendorong tingkat penyewaan yang lebih tinggi dibandingkan musim lainnya.

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %%
day_df['month'] = day_df['dteday'].dt.month

monthly_rentals = day_df.groupby('month')['cnt'].mean()

plt.figure(figsize=(10,5))

plt.plot(
    monthly_rentals.index,
    monthly_rentals.values,
    marker='o'
)

plt.title('Tren Rata-rata Penyewaan Sepeda per Bulan (2011-2012)')
plt.xlabel('Bulan')
plt.ylabel('Rata-rata Jumlah Penyewaan')
plt.xticks(range(1,13))
plt.grid(True)

plt.show()

# %% [markdown]
# **Insight:** (Opsional)
# - Jumlah penyewaan sepeda cenderung meningkat mulai awal tahun hingga pertengahan tahun.
# - Puncak rata-rata penyewaan terjadi pada bulan-bulan menielang musim Fall.
# - Setelah mencapai puncaknya, jumlah penyewaan mulai mengalami penurunan pada akhir tahun.
# - Pola ini menunjukkan adanya tren musiman yang memengaruhi perilaku pengguna layanan Bike Sharing.

# %%
workingday_analysis = day_df.groupby('workingday')['cnt'].mean()
workingday_analysis
# Out:
# workingday
# 0    4330.168831
# 1    4584.820000
# Name: cnt, dtype: float64

# %%
plt.figure(figsize=(6,4))

sns.barplot(
    x=['Holiday/Weekend', 'Working Day'],
    y=workingday_analysis.values
)

plt.title('Rata-rata Penyewaan Sepeda pada Hari Kerja dan Hari Libur')
plt.ylabel('Rata-rata Jumlah Penyewaan')

plt.show()

# %% [markdown]
# ## Conclusion & Recommendation

# %% [markdown]
# - **Conclusion pertanyaan 1:** Bagaimana pengaruh kondisi cuaca terhadap rata-rata jumlah penyewaan sepeda harian selama tahun 2011-2012?
#
# Berdasarkan hasil analisis, kondisi cuaca memiliki pengaruh yang besar terhadap jumlah penyewaan sepeda. Cuaca cerah (Clear) menghasilkan rata-rata penyewaan tertinggi, yaitu sekitar 4.877 penyewaan per hari, sedangkan kondisi Light Rain/Snow menghasilkan rata-rata penyewaan terendah, yaitu sekitar 1.803 penyewaan per hari. Temuan ini menunjuukan bahwa semakin baik kondisi cuaca, semakin tinggi tingkat penggunaan layanan Bike Sharing.
# - **Conclusion pertanyaan 2:** Bagaimana tren jumlah penyewaan sepeda berdasarkan musim selama tahun 2011-2012? dan musim mana yang memberikan kontribusi penyewaaan tertinggi?
#
# Hasil analisis menunjukkan bahwa terdapat perbedaan jumlah penyewaan sepeda pada setiap musim. Musim Fall memiliki rata-rata penyewaan tertinggi, yaitu sekitar 5.644 penyewaan per hari, diikuti oleh Summer dan Winter. Sementara itu, musim Spring memiliki rata-rata penyewaan terendah, yaitu sekitar 2.604 penyewaan per hari. Hal ini menunjukkan bahwa fakor musim berpengaruh terhadap tingkat permintaan layanan Bike Sharing.
#
# - **Conclusion pertanyaan 2:** Conclusion Analisis Lanjutan
#
# Berdasarkan analisis perbandingan hari kerja dan hari libur,ditemukan bahwa jumlah penyewaan sepeda cenderung lebih tinggi pada hari kerja dibandingkan hari libur. Temuan ini mengindikasikan bahwa layanan Bike Sharing banyak dimanfaatkan sebagai sarana transportasi untuk aktivitas sehari-hari, seperti perjalanan menuju  tempat kerja atau sekolah.

# %% [markdown]
# **Rekomendasi Action Item:**
# - 1. Optimalkan Ketersediaan Sepeda Pada Cuaca Dan Musim Dengan Permintaan Tinggi
# Menambah jumlah sepeda yang tersedia pada periode dengan cuaca cerah serta pada musim Fall dan Summer, karena permintaan cenderung lebih tinggi dibandingkan periode lainnya.
# - 2. Menyusun Strategi Promosi Pada Periode Permintaan Rendah
# Menyusun Strategi Promosi Pada Periode Permintaan Rendah
# Memberikan promo atau program loyalitas pada musim Spring maupun saat kondisi cuaca kurang mendukung untuk membantu meningkatkan jumlah penyewaan
# - 3. Memanfaatkan Prediksi Cuaca Untuk Perencanaan Operasioanal
# Menggunakan data prakiraan cuaca sebagai dasar dalam mengatur disribusi sepeda dan kapasitas layanan sehingga operasional dapat lebih efisien
# - 4. Mengoptimalkan Distribusi Sepeda Pada Hari Kerja
# Karena tingkat penyewaan lebih tinggi pada hari kerja, perusahaan dapat memprioritaskan distribusi sepeda ke lokasi dengan aktivitas komuter yang tinggi, seperti kawasan perkantoran, kampus, dan pusat transportasi
